# %% [markdown]
# # Dall'idea al programma
#
# Tutti noi alle elementari abbiamo imparato a scrivere prima ricopiando le lettere dell'alfabeto, poi formando semplici parole e infine componendo le prime frasi. Imparare a programmare segue un percorso analogo. Per prima cosa è necessario conoscere l'*alfabeto* della programmazione (ad esempio cosa intendiamo per variabile e tipo di dato), poi imparare a scrivere le prime *parole* (linee di codice eseguibili) e infine comporre semplici *frasi* (sequenze di istruzioni per ottenere un risultato).
#
# Così come la scrittura non è fine a se stessa, ma un mezzo per comunicare, così la programmazione non è fine a se stessa, ma un mezzo per implementare idee e soluzioni ai problemi che incontriamo in modo che possano essere eseguite automaticamente da un computer. Come la scrittura serve per le esigenze più diverse – messaggi agli amici, articoli di giornale, bugiardini di farmaci, romanzi – così la programmazione trova applicazione in miriadi di ambiti: analisi numerica, siti web, robotica, computer vision e molto altro. E come saper scrivere è molto diverso dal saper scrivere *bene*, così saper programmare è molto diverso dal saper programmare *bene*.
#
# In questo percorso proveremo a gettare le basi, partendo dai fondamentali per poi imparare a pensare e implementare come un vero programmatore.
#
# <!-- # Dall'idea al programma
#
# Tutti noi alle elementari abbiamo imparato a scrivere prima ricopiando le lettere dell'alfabeto, poi scrivendo semplici parole ed infine componendo le prime frasi. Imparare a programmare segue un procedimento analogo. Per prima cosa è necessario imparare l'*alfabeto* necessario per programmare (ad esempio cosa intendiamo per variabile e tipo di dato), poi a scrivere le prime *parole* (linee di codice eseguibili) e infine come comporre semplici *frasi* (sequenze di istruzioni per ottenere un risultato).
#
# Così come la scrittura non è fine a se stessa, ma un mezzo per comunicare, così programmare, cioè scrivere sequenze di istruzioni eseguibili, non è fine a se stesso, ma un mezzo per implementare idee e soluzioni per i problemi che incontriamo.
# Come la scrittura è utilizzata per le esigenze più diverse, scrivere messaggi agli amici, articoli di giornali, bugiardini di farmaci, romanzi, così la programmazione è usata in miriadi di ambiti come analisi numerica, siti web, robotica, computer vision, e molto altro. Come saper scrivere è molto diverso dal saper scrivere bene, così saper programmare è molto diverso dal saper programmare bene. In questo percorso proveremo a gettare le basi, partendo dai fondamentali per poi imparare a pensare e implementare come un programmatore. -->
#
#
# <!-- In questo modo abbiamo imparato tutti a scrivere, poi ognuno ha utilizzato questa abilità nei modi più diversi nella vita quotidiana. Si scrive ogni volta che mandiamo un messaggino ai nostri amici, una mail ai nostri colleghi, gli auguri di natale ai parenti e pure quando si fa la lista della spesa per non scordarsi che è finita la carta. C'è chi ha fatto della scrittura un mestiere ed è diventato giornalista e chi scrive relazioni su esperimenti per descrivere i risultati ottenuti.
# Saper scrivere è dunque un'abilità molto versatile e di grande valore che viene utilizzata da ognuno come mezzo di espressione secondo le proprie esigenze. Il procedimento per imparare a programmare assomiglia abbastanza a quello per imparare a scrivere in questo senso: programmare è una grande abilità molto versatile che consiste nell'imparare a scrivere formalizzare sequenze di istruzioni in linee di codice eseguibili da un computer. Tuttavia questa abilità viene utilizzata da ogni programmatore in modo diverso in base alle proprie esigenze. C'è chi programma siti web, chi programma robot, chi si occupa di modelli linuistici, chi programma schede per l'automotive e via dicendo. Quello che cercheremo di fare in questo percorso è imparare l'alfabeto necessario per programmare (cosa sono le variabili, i tipi di dato, le strutture di controllo), ad utilizzarlo per scrivere le prime semplici frasi (piccoli blocchi di codice che servono a risolvere piccoli problemi) e infine a comporre i primi testi un po' più articolati (programmi più complessi con varie funzionalità).
#
#
#
# Il materiale proposto è basato sul libro "Think Python: How to think like a computer scientist" a cui si rimanda per ulteriori aprofondimenti. -->

# %% [markdown]
# ### Identikit del programmatore
#
# 1. Problem solving: "Saper formulare domande, trovare soluzioni creative, descriverle in maniera chiara e precisa"
# 2. Formalismo: "Saper scrivere in maniera formale"
# 3. Praticità: "Saper fare considerazioni pratiche sull soluzioni proposte in base al contesto e le risorse disponibili"
# 4. Capacità analitiche: "Saper osservare fenomeni, comprenderne i meccanismi, formulare ipotesi e previsioni"

# %% [markdown]
# !!!
# Immagine mondo con identikit programmatore
# !!!

# %% [markdown]
# ## Alfabeto della programmazione

# %% [markdown]
# ### Cos'è un programma

# %% [markdown]
# Un programma consiste in una sequenza di istruzioni per risolvere un certo compito. Il tipo di compito può essere tra i più vari come eseguire un calcolo matematico (es. trovare il massimo di una funzione) oppure riprodurre una traccia audio. Per quanto diversi possano sembrare questi task, le istruzioni di base di ogni programma sono le medesime, ciò che cambia è il modo in cui sono utilizzate per manipolare i dati a disposizione.
#
# Le istruzioni fondamentali sono:
# - **Input**: acquisire dati da una fonte (tastiera, file, sensore)
# - **Output**: restituire dati a una destinazione (schermo, file, altoparlante)
# - **Operazioni matematiche e logiche**: manipolare valori numerici e booleani
# - **Strutture di controllo**: condizionare l'esecuzione di un blocco di istruzioni al verificarsi di una certa condizione o ripetere l'esecuzione del medesimo blocco di istruzioni per un certo numero di volte
#
# Un bravo programmatore è in grado di trasformare un task complesso in sequenze di istruzioni semplici ed esguibili offrendo una soluzione trasparente ed efficiente al problema considerato.

# %% [markdown]
# ### Linguaggi di programmazione

# %% [markdown]
# !!!
# Immagine mondo con linguaggi di programmazione
# !!!

# %% [markdown]
# Così come esistono molte lingue parlate in aree differenti, così anche i linguaggi di programmazione si sono diversificati per rispondere alle esigenze specifiche di chi li utilizza. Il panorama è molto variegato: i programmatori di applicazioni utilizzano Java, i sistemisti C++, in ambito scientifico e machine learning è diffuso Python, nelle applicazioni web si usano HTML e JavaScript, per i videogiochi è comune C#.
#
# La domanda sorge spontanea: con quale linguaggio dovrei iniziare?
#
# Una buona risposta, che potrebbe inizialmente sembrare controintuitiva, è: *nessuno di questi*.
#
# La prima cosa importante è concentrarsi sulla logica che sta dietro alla programmazione. Una volta compresa questa logica, è possibile trasferirla in modo trasversale a qualsiasi linguaggio. Questo approccio permette di evitare di perdersi in problemi secondari che emergono sempre quando si implementa una soluzione con un linguaggio specifico: errori di battitura, errori di compilazione, installazioni di software e pacchetti.
#
# Partiremo dunque utilizzando un linguaggio inventato, lo *pseudocodice*, che permette di descrivere in modo formale un algoritmo concentrandosi sulla logica della soluzione e rimandando i dettagli implementativi a un secondo momento.
#
# Lo pseudocodice presentato ricalca quello utilizzato nelle Olimpiadi Italiane di Informatica, a cui si rimanda per ulteriori approfondimenti. Tuttavia, abbiamo deciso di arricchire tale linguaggio con tipi aggiuntivi per renderlo più versatile e adatto agli esercizi che proporremo.

# %% [markdown]
# ### Sintassi e Semantica

# %% [markdown]
# Prima di iniziare a scrivere in pseudocodice, dobbiamo capire come funziona un linguaggio di programmazione. Ogni linguaggio, infatti, è definito da due componenti fondamentali:
#
# - **Sintassi**: l'insieme dei simboli utilizzabili e delle regole per costruire istruzioni valide.
#   *Esempio:* `c ← x + 3` è un'istruzione valida, mentre `x ← 3(*y` non lo è.
#
# - **Semantica**: il significato associato a ciascuna istruzione valida, cioè il comportamento che essa produce.
#   *Esempio:* Nell'istruzione `z ← x + y`, il simbolo `←` rappresenta un assegnamento, mentre `+` corrisponde all'operazione di somma.
#
# Nelle sezioni successive analizzeremo sintassi e semantica del nostro pseudocodice: quali simboli e parole possiamo utilizzare e qual è il loro significato. Al termine dovreste essere in grado di comprendere e scrivere programmi come i seguenti.

# %% [markdown]
# !!!
# Inserire immagini di un programma in Pseudocodice
# !!!

# %% [markdown]
# ### Parole chiave

# %% [markdown]
# Le parole chiave sono parole che hanno un significato specifico all'interno di un programma e, in quanto tali, non possono essere usate per altri scopi (ad esempio, come nomi di variabili — vedi sezione successiva).
#
# Questa è la lista delle parole chiave del nostro pseudocodice:
#
# - `function`
# - `return`
# - `if`
# - `then`
# - `else`
# - `for`
# - `in`
# - `while`
# - `do`
# - `end`
# - `variable`
#
# La funzione di ciascuna parola chiave verrà esaminata nel momento in cui introdurremo il contesto in cui compare.

# %% [markdown]
# ### Variabili e tipi

# %% [markdown]
# Una **variabile** è una sorta di contenitore per un valore, che può essere un numero, un testo o qualcosa di più complesso come una sequenza di numeri. Queste "tipologie" di variabili si chiamano, appunto, **tipi**.
#
# Nel nostro pseudocodice consideriamo i seguenti tipi:
#
# - **`integer`**: numeri interi
#   *Esempio:* 1, 5, -3, 0
#
# - **`float`**: numeri con decimali
#   *Esempio:* 1.5, -3.14, 0.0, 2.718
#
# - **`boolean`**: valori di verità
#   *Esempio:* true, false
#
# - **`char`**: singoli caratteri
#   *Esempio:* 'a', 'Z', '?', '3'

# %% [markdown]
# Una variabile è identificata da un nome univoco: a variabili diverse corrispondono nomi diversi. Un programma usa le variabili per manipolare valori che possono cambiare durante l'esecuzione del codice.
#
# Le variabili possono essere:
#
# - **Dichiarate**: dichiarare una variabile è obbligatorio e significa comunicare al programma che tale variabile esiste. Per questo motivo, la dichiarazione va fatta prima di qualunque altra operazione che coinvolge la variabile. Una dichiarazione inizia con la parola chiave `variable`, seguita dal nome della variabile, dai due punti e dal tipo della variabile.
#   *Esempio:* `variable a: integer`
#
#   > ⚠️ **Attenzione!** Subito dopo la dichiarazione, la variabile non contiene ancora nessun valore: deve essere inizializzata tramite assegnamento.
#
# - **Inizializzate e modificate tramite assegnamento**: l'assegnamento è l'operazione che assegna un valore alla variabile. Un assegnamento è costituito dal nome della variabile, seguito dall'operatore `←`, seguito dal valore da assegnare. Quest'ultimo può essere un valore semplice, un'altra variabile o, più in generale, un'espressione (ne parleremo in seguito).
#   *Esempio:* `a ← 0`
#
# - **Usate nelle espressioni**: una variabile può essere utilizzata in operazioni più complesse. Ad esempio, può essere sommata a un'altra variabile o a un valore tramite l'operatore `+`, oppure può essere confrontata tramite operatori quali `==`, `<`, `≥` e altri. Approfondiremo tutto ciò quando parleremo di operatori ed espressioni.
#   *Esempio:* `b ← a + 5`

# %% [markdown]
# ### Array
#
# Un **array** è una sequenza ordinata di valori dello stesso tipo. Il tipo si indica aggiungendo `[]` al tipo base: ad esempio `integer[]` per interi, `char[]` per caratteri.
#
# Il contenuto si scrive come una lista di valori separati da virgole tra parentesi quadre: es. [3, 7, 1, 9], ['a', 'f', 'd']
#
# #### Accesso agli elementi
#
# Per accedere a un elemento, si scrive il nome dell'array seguito dall'indice tra parentesi quadre.
# L'indice può essere un numero o un'espressione. Gli elementi possono essere usati e modificati come normali variabili:
# ```
# arr[0] ← 0
# arr[i] ← arr[i] + 1
# ```
#
# > ⚠️ **Attenzione!**
# >
# > 1. **Indicizzazione**: Un array di lunghezza `n` è indicizzato da `0` a `n − 1`.
# >    Nell'array [3, -1, 8], l'elemento in posizione 1 è -1.
# >
# > 2. **Dichiarazione**: Quando si dichiara un array, si può specificarne la lunghezza tra parentesi quadre.
# >    Se non si inizializza l'array con dei valori, è **obbligatorio** specificare la lunghezza:
# >    ```
# >    variable a: integer[10]
# >    a[2] ← 0               # OK
# >
# >    variable b: integer[]
# >    b[2] ← 0               # Errore!
# >    ```
# >
# > 3. **Stringhe**: Gli array di caratteri `char[]` sono comunemente chiamati **stringhe**.

# %% [markdown]
# ### Operatori

# %% [markdown]
# Un **operatore** è un simbolo o una parola che combina una o più espressioni per produrre un nuovo valore. Esistono diverse classi di operatori:
#
# - **Operatori aritmetici**, combinano due valori numerici e restituiscono un valore numerico.
#   Consideriamo i seguenti operatori **`+`**, **`-`**, **`x`**, **`/`**, **`mod`** (addizione, sottrazione, moltiplicazione, divisione intera, resto della divisione intera). L'operatore **`−`** può anche essere usato come operatore unario per cambiare il segno: *Esempio:* se a vale 3, allora −a vale −3. L'operatore **`/`** utilizzato sui numeri float restituisce il valore frazionario.
#
# - **Operatori di confronto**, combinano due valori e restituiscono un valore booleano.
#   Consideriamo i seguenti operatori **`==`**, **`≠`**, **`<`**, **`≤`**, **`>`**, **`≥`**
#
# - **Operatori logici**, combinano due valori booleani e restituiscono un valore booleano.
#   Consideriamo i seguenti operatori **`and`**, **`or`**, **`not`**
#
# > ⚠️ **Attenzione!** Il simbolo di uguaglianza è `==` (due uguali separati da uno spazio), da non confondere con l'assegnamento `←`.
#
# Se in una espressione compaiono più operatori differenti, l'ordine di precedenza è il seguente:
# 1. **Massima precedenza**: `×`, `/`, `mod` (moltiplicazione, divisione, modulo)
# 2. **Media precedenza**: `+`, `−` (addizione, sottrazione)
# 3. **Bassa precedenza**: `==`, `≠`, `<`, `≤`, `>`, `≥` (confronti)
# 4. **Minima precedenza**: `and`, `or`, `not` (operatori logici)
#
# Per evitare ambiguità, è buona prassi utilizzare le **parentesi tonde** `()` per specificare esplicitamente l'ordine delle operazioni.

# %% [markdown]
# ### Espressioni
#
# Un'**espressione** è un pezzo di codice che può essere valutato per produrre un valore.
# Sono espressioni:
#
# 1. **Singole variabili**  *Esempio:* a, B[i]
#
# 2. **Valori letterali**  *Esempio:* 42, 3.14, true, 'a', [1, 2, 3]
#
# 3. **Chiamate a funzione** *Esempio:* max(a, b)
#
# 4. **Composizione di due espressioni** *Esempio:* Se espr1 ed espr2 sono espressioni, anche espr1 + espr2 è un'espressione
#
# Le espressioni possono essere utilizzate per assegnare un valore ad una variabile (es. a ← b mod 10), passare un argomento ad una funzione o come componenti di altre espressioni.

# %% [markdown]
# ## Le prime frasi

# %% [markdown]
# Con gli elementi  introdotti fino ad ora possiamo iniziare a scrivere i primi semplici programmi. Ad esempio:
#
#     variable somma: integer
#     sum ← 1
#     sum ← sum + 2
#     sum ← sum + 3
#     output(sum)
#
# Il commputer eseguirà un'istruzione dopo l'altra fino a stampare a video 6. Dopo poco però, ci si accorge che fissare l'ordine di esecuzione delle istruzioni limita molto la flessibilità e utilità dei programmi.
#
# Per scrivere programmi più potenti e generali infatti, abbiamo bisogno di **strutture di controllo** che permettano di:
# - Eseguire istruzioni solo se si verificano determinate condizioni
# - Ripetere blocchi di codice più volte
#
# Ciò permette di diversificare il comportamento in base allo stato in cui si trova il programma e evitare di riscrivere molte volte le medesime istruzioni risparmiando tempo e prevenendo potenziali errori.

# %% [markdown]
# ### Strutture di controllo

# %% [markdown]
# Una **struttura di controllo** è un costrutto che racchiude un blocco di istruzioni, detto **corpo**. A seconda del tipo, le istruzioni nel corpo possono essere eseguite condizionalmente o ripetute. Le strutture di controllo possono essere **annidate**, cioè il corpo di una struttura può contenerne altre.
#
# Il nostro pseudocodice utilizza tre tipi di strutture di controllo: condizionali (`if`) e cicli (`while` e `for`).

# %% [markdown]
# #### If statement
#
# Le strutture condizionali permettono di eseguire codice solo se una condizione è vera.
#
# **Sintassi if-else if-else:**
#
#     if {condizione_1} then:
#         {corpo if}
#     else if {condizione_2} then:
#         {corpo else if}
#     else:
#         {corpo else}
#     end if
#
# Qui {condizione_1} e {condizione_2} sono espressioni booleane. Se {condizione_1} è true, viene eseguito {corpo if}, altrimenti se {condizione_2} è true, viene eseguito {corpo else if}, altrimenti viene eseguito {corpo else}.
#
# **Esempio:**
#
#     variable temperatura: integer
#     temperatura ← 20
#
#     if temperatura < 18 then:
#         output("Freddo")
#     else if temperatura < 21 then:
#         output("Tiepido")
#     else:
#         output("Caldo")
#     end if

# %% [markdown]
# #### Ciclo for
#
# Il ciclo `for` itera su un intervallo di numeri interi consecutivi.
#
# **Sintassi:**
# ```
# for {indice} in {intervallo} do
#     {corpo}
# end for
# ```
#
# **Componenti:**
# - **`{indice}`**: variabile temporanea (tipicamente `i`, `j`, `k`) che assume automaticamente i valori dell'intervallo. Non va dichiarata ed esiste solo all'interno del ciclo.
# - **`{intervallo}`**: sequenza di numeri consecutivi, scritta come `[a ... b)`, che rappresenta tutti gli interi da `a` (incluso) a `b` (escluso).
#
# > 💡 **Notazione degli intervalli:** `[a ... b)` è un intervallo **semiaperto** che include `a` ma esclude `b`.
# >
# > Esempi:
# > - `[1 ... 4)` = {1, 2, 3}
# > - `[0 ... 5)` = {0, 1, 2, 3, 4}
# > - `[7 ... 8)` = {7}
#
# Questa notazione è standard in programmazione e rende naturale iterare sugli array: un array di lunghezza `n` ha indici `[0 ... n)`.
#
# **Esempio 1 - Stampare i numeri da 0 a n-1:**
# ```
# variable n: integer
# n ← 10
#
# for i in [0 ... n) do
#     output(i)
# end for
# ```
#
# **Esempio 2 - Sommare gli elementi di un array:**
# ```
# variable v: integer[]
# variable n: integer
# variable somma: integer
# v ← [3, 7, 2, 9]
# n ← 4
# somma ← 0
#
# for i in [0 ... n) do
#     somma ← somma + v[i]
# end for
#
# output(somma)  // Stampa 21
# ```
#
# **Esempio 3 - Verificare se un array contiene elementi duplicati:**
# ```
# variable v: integer[]
# variable n: integer
# variable equal_pair: boolean
# v ← [3, 7, 2, 9, 7]
# equal_pair ← false
# n ← 5
#
# for i in [0 ... n) do
#     for j in [i+1 ... n) do
#         if v[i] == v[j] then
#             equal_pair ← true
#         end if
#     end for
# end for
#
# output(equal_pair)  // Stampa true
# ```
#
# Questo esempio usa **cicli annidati**. Il primo ciclo itera su ogni elemento dell'array tramite `i`, il secondo itera sugli elementi successivi tramite `j`. Questo è il modo standard per esaminare tutte le coppie di indici distinti. Alla fine, `equal_pair` vale `true` se e solo se è stata trovata una coppia di elementi uguali.

# %% [markdown]
# ## Testi complessi

# %% [markdown]
# ### Funzioni

# %% [markdown]
# Una **funzione** è un blocco di pseudocodice racchiuso tra le parole chiave `function` e `end function`. Le funzioni servono principalmente per:
#
# - **Riutilizzare codice**: permettono di invocare lo stesso blocco di istruzioni in punti diversi del programma (a differenza dei cicli, dove il corpo viene eseguito consecutivamente)
# - **Abilitare la ricorsione**: una funzione può chiamare se stessa
#
# #### Componenti di una funzione
#
# Una funzione è composta da:
#
# 1. **Nome**: identifica univocamente la funzione e permette di invocarla
#    *Esempio:* calcola_media, trova_massimo
#
# 2. **Parametri** (opzionali): variabili che ricevono i valori passati alla funzione
#    *Sintassi:* var1: tipo1, var2: tipo2, ...
#    Una funzione può non avere parametri.
#
# 3. **Corpo**: sequenza di istruzioni eseguite quando la funzione viene chiamata
#
# 4. **Tipo di ritorno** (opzionale): tipo del valore restituito dalla funzione
#    *Esempio:* una funzione che somma due interi restituisce un integer
#
# #### Sintassi
#
# **Funzione senza valore di ritorno:**
# ```
# function nome_funzione(param1: tipo1, param2: tipo2, ...)
#     {corpo}
# end function
# ```
#
# **Funzione con valore di ritorno:**
# ```
# function nome_funzione(param1: tipo1, param2: tipo2, ...) → tipo_ritorno
#     {corpo}
# end function
# ```
#
# Se non ci sono parametri, si scrive semplicemente `nome_funzione()`.
#
# > 💡 **Nota:** I parametri (`param1`, `param2`, ...) sono variabili utilizzabili solo all'interno della funzione. I loro valori vengono definiti al momento della chiamata e possono variare tra chiamate diverse.
#
# #### La parola chiave return
#
# La parola chiave `return` serve a:
# - Restituire un valore al chiamante (obbligatorio per funzioni con tipo di ritorno)
# - Interrompere immediatamente l'esecuzione della funzione
#
# Quando viene eseguito un `return`, il programma esce dalla funzione e riprende dal punto in cui era stata chiamata, sostituendo la chiamata con il valore restituito.
#
# **Esempio 1 - Funzione che somma due numeri:**
# ```
# function add(a: integer, b: integer) → integer
#     return a + b
# end function
#
# // Uso della funzione
# variable x: integer
# variable y: integer
# variable somma: integer
# x ← -2
# y ← 5
#
# somma ← add(x, y)    // somma assume il valore 3
# ```
#
# La funzione add prende due parametri interi e restituisce la loro somma. Alla riga 8, vengono passati come argomenti x (che vale -2) e y (che vale 5), quindi add restituisce 3.
#
# **Esempio 2 - Return multipli:**
#
# Una funzione può contenere più istruzioni `return`. L'esecuzione termina al primo `return` incontrato.
# ```
# function absolute_value(n: integer) → integer
#     if n ≥ 0 then
#         return n
#     end if
#     return -n
# end function
# ```
#
# Se `n ≥ 0`, il programma entra nell'`if`, esegue `return n` ed esce immediatamente dalla funzione. Altrimenti, salta l'`if` ed esegue il secondo `return`.
#
# **Esempio 3 - Return vuoto:**
#
# Per funzioni senza tipo di ritorno, si può usare `return` (senza valore) per uscire anticipatamente:
# ```
# function print_absolute_value(n: integer)
#     if n ≥ 0 then
#         output(n)
#         return
#     end if
#     output(-n)
# end function
# ```
#
# #### Chiamare una funzione
#
# **Chiamare** (o invocare) una funzione significa trasferire temporaneamente l'esecuzione all'inizio della funzione, passando una lista di **argomenti**.
#
# **Distinzione importante:**
# - **Parametri**: variabili nella definizione della funzione (hanno nome e tipo)
# - **Argomenti**: valori concreti passati in una specifica chiamata (risultato di espressioni)
#
# Gli argomenti devono:
# - Essere in numero uguale ai parametri
# - Avere tipi corrispondenti ai parametri
#
# **Esempio:**
# ```
# function moltiplica(a: integer, b: integer) → integer
#     return a × b
# end function
#
# variable risultato: integer
# risultato ← moltiplica(3 + 2, 4)    // passa 5 e 4 come argomenti
# output(risultato)                    // stampa 20
# ```
#
# Anche `output` è una funzione (senza tipo di ritorno con un parametro).

# %% [markdown]
# #### Funzioni ricorsive
#
# Una **funzione ricorsiva** è una funzione che chiama se stessa. Questo è uno strumento potente che permette di risolvere problemi complessi scomponendoli in sottoproblemi più semplici.
#
# Quando una funzione chiama se stessa:
# 1. Il programma inizia una nuova esecuzione della funzione con nuovi argomenti
# 2. L'esecuzione precedente resta "sospesa"
# 3. Quando la chiamata interna termina, l'esecuzione precedente riprende
# 4. Le variabili dell'esecuzione sospesa mantengono i loro valori
#
# **Esempio classico - Calcolo del fattoriale:**
#
# Il fattoriale di un intero positivo `n`, indicato con `n!`, è il prodotto `1 × 2 × ... × n`.
# ```
# function factorial(n: integer) → integer
#     if n == 1 then
#         return 1
#     end if
#     return n × factorial(n - 1)
# end function
# ```
#
# La funzione sfrutta la proprietà matematica `n! = n × (n-1)!`. L'`if` alle righe 2-4 è il **caso base** che arresta la ricorsione: quando `n` diventa `1`, viene restituito `1` senza ulteriori chiamate.
#
# **Esempio di esecuzione:**
# ```
# factorial(4)
# → 4 × factorial(3)
# → 4 × (3 × factorial(2))
# → 4 × (3 × (2 × factorial(1)))
# → 4 × (3 × (2 × 1))
# → 4 × (3 × 2)
# → 4 × 6
# → 24
# ```
#
# > ⚠️ **Attenzione!** Ogni funzione ricorsiva deve avere un caso base che interrompe la ricorsione, altrimenti si creerebbe un ciclo infinito.

# %% [markdown]
# ## Programmare per risolvere problemi
#
# Ora hai tutte le basi teoriche per comprendere la logica di qualsiasi linguaggio di programmazione. Imparare un linguaggio specifico richiederà semplicemente di tradurre i concetti dallo pseudocodice alla sintassi del linguaggio scelto quindi non dovrebbe richiedere troppo tempo.
#
# ### Dallo pseudocodice ai linguaggi reali
#
# Ecco come alcuni costrutti fondamentali si traducono nei linguaggi più diffusi:
#
# | Pseudocodice | Python | C++ | Java |
# |--------------|--------|-----|------|
# | `variable x: integer` | `x = 0` | `int x;` | `int x;` |
# |`x ← 5` | `x = 5` | `x = 5;` | `x = 5;` |
# | `if x > 0 then`<br>&nbsp;&nbsp;`...`<br>`end if` | `if x > 0:`<br>&nbsp;&nbsp;&nbsp;&nbsp;`...` | `if (x > 0) {`<br>&nbsp;&nbsp;&nbsp;&nbsp;`...`<br>`}` | `if (x > 0) {`<br>&nbsp;&nbsp;&nbsp;&nbsp;`...`<br>`}` |
# | `for i in [0 ... n) do`<br>&nbsp;&nbsp;`...`<br>`end for` | `for i in range(n):`<br>&nbsp;&nbsp;&nbsp;&nbsp;`...` | `for (int i=0; i<n; i++) {`<br>&nbsp;&nbsp;&nbsp;&nbsp;`...`<br>`}` | `for (int i=0; i<n; i++) {`<br>&nbsp;&nbsp;&nbsp;&nbsp;`...`<br>`}` |
# | `while x > 0 do`<br>&nbsp;&nbsp;`...`<br>`end while` | `while x > 0:`<br>&nbsp;&nbsp;&nbsp;&nbsp;`...` | `while (x > 0) {`<br>&nbsp;&nbsp;&nbsp;&nbsp;`...`<br>`}` | `while (x > 0) {`<br>&nbsp;&nbsp;&nbsp;&nbsp;`...`<br>`}` |
# | `function square(a: integer) → integer`<br>&nbsp;&nbsp;`return a x a`<br>`end function` | `def square(a):`<br>&nbsp;&nbsp;&nbsp;&nbsp;`return a x a` | `int square(int a) {`<br>&nbsp;&nbsp;&nbsp;&nbsp;`return a x a;`<br>`}` | `int square(int a) {`<br>&nbsp;&nbsp;&nbsp;&nbsp;`return a x a;`<br>`}` |
# | `variable arr: integer[] ← [1, 2, 3]` | `arr = [1, 2, 3]` | `int arr[] = {1, 2, 3};` | `int[] arr = {1, 2, 3};` |
# | `output(x)` | `print(x)` | `cout << x;` | `System.out.println(x);` |
#
# Come puoi notare, la struttura logica rimane invariata: cambiano principalmente simboli, parole chiave e convenzioni sintattiche (come l'uso di parentesi graffe, punti e virgola, o indentazione).
#
# ### Da saper scrivere a scrivere bene
#
# Conoscere la sintassi è solo l'inizio. Saper programmare *bene* è tutta un'altra sfida e richiede:
#
# - **Pratica costante**: risolvere molti problemi diversi
# - **Capacità di analisi**: scomporre problemi complessi in sottoproblemi semplici
# - **Efficienza**: scrivere codice che non sia solo corretto, ma anche veloce ed elegante
# - **Leggibilità**: produrre codice chiaro e manutenibile
# - **Debugging**: imparare a individuare e correggere errori
#
# <!-- ### Risorse per esercitarsi
#
# Ecco alcune piattaforme eccellenti per allenare le tue abilità di programmazione:
#
# **Per principianti:**
# - [**Esercizi delle Olimpiadi Italiane di Informatica**](https://training.olinfo.it/) - Problemi in italiano, dal livello base all'avanzato
# - [**Codewars**](https://www.codewars.com/) - Sfide di programmazione organizzate per difficoltà crescente
# - [**HackerRank**](https://www.hackerrank.com/) - Esercizi strutturati su algoritmi e strutture dati
#
# **Per livello intermedio e avanzato:**
# - [**LeetCode**](https://leetcode.com/) - Problemi algoritmici, molto usati per preparare colloqui tecnici
# - [**Codeforces**](https://codeforces.com/) - Competizioni di programmazione competitive
# - [**Project Euler**](https://projecteuler.net/) - Problemi matematici da risolvere con la programmazione
#
# **Per progetti pratici:**
# - [**GitHub**](https://github.com/) - Esplora progetti open source e impara dal codice altrui
# - [**Kaggle**](https://www.kaggle.com/) - Competizioni di data science e machine learning (se ti interessa questo ambito)
#
# ### Consigli finali
#
# 1. **Inizia con problemi semplici** e aumenta gradualmente la difficoltà
# 2. **Non limitarti a far funzionare il codice**: chiediti sempre se può essere migliorato
# 3. **Leggi codice scritto da altri** programmatori esperti per imparare nuove tecniche
# 4. **Partecipa a comunità** online (forum, Discord, Reddit) per confrontarti e chiedere aiuto
# 5. **Sii paziente**: diventare bravi richiede tempo e molti errori lungo il percorso
#
# La programmazione è un'abilità che si affina con l'esperienza. Ogni problema risolto ti insegna qualcosa di nuovo. Non scoraggiarti davanti alle difficoltà: fanno parte del processo di apprendimento.
#
# **In bocca al lupo per il tuo percorso da programmatore!** 🚀 -->
