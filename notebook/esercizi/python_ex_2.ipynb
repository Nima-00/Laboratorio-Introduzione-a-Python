# %% [markdown]
# # Laboratorio: Foglio Esercizi 2

# %% [markdown]
# ### Ex 1: Stampare gli elementi di un array

# %% [markdown]
#     function stampa_array(...):
#         ...
#     end function

# %%
# Implementazione in Python

# %% [markdown]
# ### Ex 2: Stampare gli elementi pari

# %% [markdown]
#     function stampa_array_pari(...):
#         ...
#     end function

# %%
# Implementazione in Python

# %% [markdown]
# ### Ex 3: Stampa elementi in posizione pari o dispari in base a ciò che è richiesto

# %% [markdown]
#     function stampa_elementi_array(...):
#         ...
#     end function

# %%
# Implementazione in Python

# %% [markdown]
# ### Ex 4: Somma array

# %% [markdown]
#     function somma_array(...):
#         ...
#     end function

# %%
# Implementazione in Python

# %% [markdown]
# ### Ex 5: inverti array

# %% [markdown]
#     function inverti_array(...):
#         ...
#     end function

# %%
# Implementazione in Python

# %% [markdown]
# ### Ex 6: Ritorna array con elementi in posizione pari

# %% [markdown]
#     function elementi_pari(...):
#         ...
#     end function

# %%
# Implementazione in Python

# %% [markdown]
# ### Ex 7: Stampa le singole cifre di un numero

# %% [markdown]
#     function stampa_singole_cifre(...):
#         ...
#     end function

# %%
# Implementazione in Python

# %% [markdown]
# ### Ex 8: Somma delle cifre di un numero

# %% [markdown]
#     function somma_cifre(...):
#         ...
#     end function

# %%
# Implementazione in Python

# %% [markdown]
# ### Ex 9: Numero cifre pari

# %% [markdown]
#     function n_cifre_pari(...):
#         ...
#     end function

# %%
# Implementazione in Python

# %% [markdown]
# ### Ex 10: Inverti l'ordine delle cifre

# %% [markdown]
#     function inverti_cifre(...):
#         ...
#     end function

# %%
# Implementazione in Python
