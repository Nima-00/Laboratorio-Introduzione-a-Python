# %% [markdown]
# # Laboratorio 4

# %% [markdown]
# ### Ex 1: Stampa multipli
#
# Scrivi una funzione **stampa_multipli** che prende in input due numeri n e m e stampa a video i multipli di n da 0 a mn.

# %% [markdown]
# <!-- Pseudocodice -->
#
#     function stampa_multipli(...):
#         ...
#     end function

# %%
# Implementazione in Python

# %% [markdown]
# ### Ex 2: Successione di Fibonacci
#
# La successione di Fibonacci inizia con i termini F_0 = 0 e F_1 = 1. Da qui in poi ogni termine è calcolato come la somma dei due preccedenti. Scrivi una funzione che prende in input un intero n e restituisca come output F_n, l'ennesimo elemento della successione di Fibonacci.

# %% [markdown]
# <!-- Pseudocodice -->
#
#     function fibonacci(...):
#         ...
#     end function

# %%
# Implementazione in Python

# %% [markdown]
# ### Ex 3: Somma elementi in posizione pari e somma elementi in posizione dispari
#
# Scrivi una funzione che prende in input un array e la sua lunghezza e restituisca come output la somma degli elementi in posizione pari e la somma degli elementi in posizione dispari.

# %% [markdown]
# <!-- Pseudocodice -->
#
#     function somma_array(...):
#         ...
#     end function

# %%
# Implementazione in Python

# %% [markdown]
# ### Ex 4: Prodotto delle cifre pari
#
# Scrivi una funzione che prende in input un numero intero e restituisce il prodotto delle cifre pari

# %% [markdown]
# <!-- Pseudocodice -->
#
#     function prodotto_cifre_pari(...):
#         ...
#     end function

# %%
# Implementazione in Python

# %% [markdown]
# ### Ex 5: Trovare i tre numeri più piccoli in un array
#
# Scrivi una funzione che prenda in input un array e la sua lunghezza e restituisca i tre numeri più piccoli.
#
# **Nota:** il numero max contenuto nell'array di input è 100

# %% [markdown]
# <!-- Pseudocodice -->
#
#     function tre_min(...):
#         ...
#     end function
