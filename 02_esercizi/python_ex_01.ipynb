# %% [markdown]
# # Laboratorio 1

# %% [markdown]
# ### Ex 1: Conversione Decimale Binario

# %% [markdown]
# Pseudocodice
#
# ```
# function dec_to_bin(n: integer) -> integer
#     ...
# end function
# ```

# %%
# Implementazione in Python

# %% [markdown]
# ### Ex 2: Conversione Binario Decimale

# %% [markdown]
# Pseudocodice
#
# ```
# function bin_to_dec(n: integer) -> integer
#     ...
# end function
# ```

# %%
# Implementazione in Python

# %% [markdown]
# ### Ex 3: Massimo Comune Divisore

# %% [markdown]
# Pseudocodice
#
# ```
# function alg_euclide(a: integer, b: integer) -> integer:
#     ...
# end function
# ```

# %%
# Implementazione in Python

# %% [markdown]
# ### Ex 4: Trovare il massimo numero di 1 consecutivi

# %% [markdown]
# Pseudocodice
#
# ```
# function alg_euclide(a: integer) -> integer:
#     ...
# end function
# ```

# %%
# Implementazione in Python

# %% [markdown]
# ### Ex 5: numero di numeri con un numero pari di cifre

# %% [markdown]
# Pseudocodice
#
# ```
# function n_pari_couter(a: integer[]) -> integer:
#     ...
# end function
# ```

# %%
# Implementazione in Python
